# %% [markdown]
# # Power

# %%
from joblib import Parallel, delayed
from tqdm import tqdm

import numpy as np
import polars as pl
from gpy_test import GPY
from scipy.linalg import sqrtm
import pickle
from pathlib import Path
from typing import Callable

from data import (
    white_arma_sample,
    arma_covariance,
    non_linear_sample,
    factor_model_sample,
    arch_sample,
)

# %%
# for the GPY test, we will always use the following test functions
fs = [lambda x: x, lambda x: x**2]

# we will always evaluate the test against these values of N and M
T_range = np.arange(50, 400 + 50, 50)
M_range = np.arange(50, 400 + 50, 50)

# always repeat an experiment 1000 times
n_repeats = 100

# always throw the first 100 time series samples
burn = 100

# threshold to detect
level = 0.05

# generate real gaussian dataXC
is_complex_gaussian = False

# path to the stored experiment results for easy reloading
data_filepath_format = "data/{experiment_type}/{experiment_id}.pickle"

# %%
# Define the functions to store and load experiment results
def run_batch(
    run: Callable, n_repeats: int, experiment_type: str, run_kwargs: dict
) -> None:
    experiment_id = "_".join(f"{key}={value}" for key, value in run_kwargs.items())
    resolved_data_path = Path(
        data_filepath_format.format(
            experiment_type=experiment_type, experiment_id=experiment_id
        )
    )
    if resolved_data_path.exists():
        return

    resolved_data_path.parent.mkdir(parents=True, exist_ok=True)

    results = [run(**run_kwargs) for _ in range(n_repeats)]
    with open(resolved_data_path, "wb") as handle:
        pickle.dump(results, handle)


def load_batch(experiment_type: str) -> pl.DataFrame:
    # load the samples
    all_results = []

    resolved_data_path = Path(
        data_filepath_format.format(
            experiment_type=experiment_type, experiment_id="none"
        )
    ).parent
    for file in resolved_data_path.iterdir():
        if file.stem == ".DS_Store":
            continue

        with open(file, "rb") as handle:
            results = pickle.load(handle)
        all_results += results

    return pl.DataFrame(all_results)

# %% [markdown]
# # Level check
# # MA time series

# %%
def run(T, M, burn, time_ar, time_ma, space_ar, space_ma, is_complex_gaussian):
    y = white_arma_sample(
        T, M, burn, ar=time_ar, ma=time_ma, is_complex_gaussian=is_complex_gaussian
    )
    space_cov = arma_covariance(M, space_ar, space_ma)
    space_cov_sqrt = sqrtm(space_cov)
    y = y @ space_cov_sqrt
    gpy_result = GPY(y, fs, is_complex_gaussian=is_complex_gaussian)
    return {
        "T": T,
        "M": M,
        "burn": burn,
        "time_ar": time_ar,
        "time_ma": time_ma,
        "space_ar": space_ar,
        "space_ma": space_ma,
        "is_complex_gaussian": is_complex_gaussian,
        "test_statistic": gpy_result.test_statistic,
        "p_value": gpy_result.p_value,
    }


time_ar, time_ma = 0.2, 0
space_ar, space_ma = 0, 0

tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "ma_no_dependence",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "time_ar": time_ar,
                "time_ma": time_ma,
                "space_ar": space_ar,
                "space_ma": space_ma,
                "is_complex_gaussian": is_complex_gaussian,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("ma_no_dependence")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(
    (pl.col("test_statistic") > 1.4).alias(positive_column_name).cast(pl.Float64)
).group_by(["T", "M", "time_ar", "time_ma"]).mean().to_pandas().pivot(
    index="T", columns=["M"], values=[positive_column_name]
)
# Out:
# 100%|██████████| 64/64 [00:06<00:00,  9.50it/s]
#     positive - 5%
# M             50    100   150   200   250   300   350   400
# T
# 50           0.44  0.41  0.35  0.37  0.29  0.26  0.28  0.29
# 100          0.44  0.43  0.40  0.50  0.46  0.40  0.41  0.39
# 150          0.60  0.54  0.41  0.40  0.48  0.39  0.38  0.35
# 200          0.58  0.56  0.49  0.43  0.51  0.43  0.40  0.49
# 250          0.57  0.65  0.54  0.46  0.41  0.51  0.41  0.38
# 300          0.69  0.55  0.60  0.58  0.45  0.43  0.43  0.34
# 350          0.61  0.55  0.59  0.52  0.45  0.48  0.42  0.45
# 400          0.68  0.62  0.48  0.52  0.46  0.48  0.61  0.41

# %% [markdown]
# ## AR time series

# %%
time_ar, time_ma = 0, 0.8
space_ar, space_ma = 0, 0

tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "ar_no_dependence",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "time_ar": time_ar,
                "time_ma": time_ma,
                "space_ar": space_ar,
                "space_ma": space_ma,
                "is_complex_gaussian": is_complex_gaussian,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("ar_no_dependence")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(
    (pl.col("test_statistic") > 1.4).alias(positive_column_name).cast(pl.Float64)
).group_by(["T", "M", "time_ar", "time_ma"]).mean().to_pandas().pivot(
    index="T", columns=["M"], values=[positive_column_name]
)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#     positive - 5%
# M             50    100   150   200   250   300   350   400
# T
# 50           0.42  0.35  0.35  0.28  0.37  0.35  0.29  0.36
# 100          0.46  0.41  0.52  0.34  0.33  0.41  0.33  0.34
# 150          0.54  0.48  0.43  0.38  0.37  0.39  0.44  0.32
# 200          0.58  0.53  0.45  0.43  0.45  0.47  0.33  0.46
# 250          0.49  0.53  0.44  0.43  0.55  0.45  0.43  0.32
# 300          0.55  0.57  0.44  0.41  0.45  0.45  0.42  0.38
# 350          0.68  0.59  0.49  0.44  0.43  0.47  0.37  0.41
# 400          0.69  0.56  0.58  0.49  0.51  0.47  0.49  0.41

# %% [markdown]
# ## ARMA time series

# %%
time_ar, time_ma = 0.2, 0.8
space_ar, space_ma = 0, 0

tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "arma_no_dependence",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "time_ar": time_ar,
                "time_ma": time_ma,
                "space_ar": space_ar,
                "space_ma": space_ma,
                "is_complex_gaussian": is_complex_gaussian,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("arma_no_dependence")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(
    (pl.col("test_statistic") > 1.4).alias(positive_column_name).cast(pl.Float64)
).group_by(["T", "M", "time_ar", "time_ma"]).mean().to_pandas().pivot(
    index="T", columns=["M"], values=[positive_column_name]
)
# Out:
#     positive - 5%
# M             50    100   150   200   250   300   350   400
# T
# 50           0.45  0.32  0.31  0.24  0.41  0.27  0.24  0.33
# 100          0.42  0.39  0.34  0.38  0.36  0.33  0.35  0.41
# 150          0.51  0.44  0.52  0.40  0.39  0.40  0.44  0.32
# 200          0.56  0.37  0.37  0.42  0.34  0.38  0.42  0.38
# 250          0.47  0.56  0.47  0.44  0.42  0.45  0.40  0.31
# 300          0.63  0.44  0.41  0.42  0.49  0.41  0.43  0.47
# 350          0.63  0.60  0.47  0.42  0.54  0.41  0.47  0.41
# 400          0.62  0.49  0.47  0.51  0.48  0.39  0.40  0.36

# %% [markdown]
# # Power check
# ## MA covariance structure

# %%
# MA covariance structure
time_ar, time_ma = 0.2, 0.8
space_ar, space_ma = 0, 0.8

tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "ma_dependence",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "time_ar": time_ar,
                "time_ma": time_ma,
                "space_ar": space_ar,
                "space_ma": space_ma,
                "is_complex_gaussian": is_complex_gaussian,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("ma_dependence")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(
    (pl.col("test_statistic") > 1.4).alias(positive_column_name).cast(pl.Float64)
).group_by(
    ["T", "M", "time_ar", "time_ma", "space_ar", "space_ma"]
).mean().to_pandas().pivot(
    index="T", columns=["M"], values=[positive_column_name]
)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#     positive - 5%
# M             50    100   150   200   250   300   350   400
# T
# 50           0.45  0.43  0.39  0.42  0.33  0.45  0.48  0.47
# 100          0.49  0.47  0.51  0.51  0.43  0.52  0.38  0.42
# 150          0.51  0.44  0.55  0.48  0.50  0.49  0.43  0.44
# 200          0.48  0.49  0.46  0.55  0.51  0.52  0.38  0.44
# 250          0.55  0.56  0.51  0.52  0.50  0.45  0.52  0.46
# 300          0.60  0.47  0.49  0.54  0.50  0.54  0.55  0.44
# 350          0.54  0.55  0.54  0.48  0.47  0.54  0.54  0.52
# 400          0.58  0.55  0.65  0.43  0.42  0.47  0.53  0.46

# %% [markdown]
# ## AR covariance structure

# %%
# AR covariance structure
time_ar, time_ma = 0.2, 0.8
space_ar, space_ma = 0.2, 0

# real gaussian data
is_complex_gaussian = False

tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "ar_dependence",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "time_ar": time_ar,
                "time_ma": time_ma,
                "space_ar": space_ar,
                "space_ma": space_ma,
                "is_complex_gaussian": is_complex_gaussian,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("ar_dependence")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(
    (pl.col("test_statistic") > 1.4).alias(positive_column_name).cast(pl.Float64)
).group_by(
    ["T", "M", "time_ar", "time_ma", "space_ar", "space_ma"]
).mean().to_pandas().pivot(
    index="T", columns=["M"], values=[positive_column_name]
)
# Out:
#     positive - 5%
# M             50    100   150   200   250   300   350   400
# T
# 50           0.47  0.32  0.41  0.36  0.35  0.30  0.41  0.33
# 100          0.48  0.47  0.43  0.32  0.43  0.34  0.37  0.31
# 150          0.55  0.50  0.51  0.42  0.46  0.32  0.31  0.40
# 200          0.59  0.50  0.51  0.37  0.45  0.43  0.44  0.40
# 250          0.59  0.48  0.51  0.48  0.38  0.34  0.40  0.36
# 300          0.60  0.54  0.50  0.41  0.45  0.38  0.44  0.44
# 350          0.58  0.54  0.51  0.41  0.36  0.45  0.44  0.46
# 400          0.61  0.59  0.48  0.51  0.51  0.47  0.44  0.48

# %% [markdown]
# ## ARMA covariance structure

# %%
time_ar, time_ma = 0.2, 0.8
space_ar, space_ma = 0.2, 0.8

tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "arma_dependence",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "time_ar": time_ar,
                "time_ma": time_ma,
                "space_ar": space_ar,
                "space_ma": space_ma,
                "is_complex_gaussian": is_complex_gaussian,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("arma_dependence")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(
    (pl.col("test_statistic") > 1.4).alias(positive_column_name).cast(pl.Float64)
).group_by(
    ["T", "M", "time_ar", "time_ma", "space_ar", "space_ma"]
).mean().to_pandas().pivot(
    index="T", columns=["M"], values=[positive_column_name]
)
# Out:
#     positive - 5%
# M             50    100   150   200   250   300   350   400
# T
# 50           0.51  0.51  0.56  0.46  0.38  0.48  0.52  0.47
# 100          0.51  0.60  0.42  0.39  0.51  0.46  0.50  0.40
# 150          0.60  0.54  0.51  0.51  0.49  0.52  0.43  0.49
# 200          0.57  0.45  0.54  0.62  0.51  0.53  0.49  0.58
# 250          0.55  0.52  0.56  0.58  0.52  0.50  0.57  0.57
# 300          0.57  0.64  0.50  0.61  0.55  0.48  0.47  0.47
# 350          0.58  0.52  0.56  0.51  0.51  0.43  0.49  0.59
# 400          0.59  0.58  0.50  0.53  0.50  0.48  0.46  0.52

# %% [markdown]
# ## Non linear dependence

# %%
def run(T: int, M: int, burn: int):
    y = non_linear_sample(T, M, burn)
    gpy_result = GPY(y, fs)
    return {
        "T": T,
        "M": M,
        "burn": burn,
        "test_statistic": gpy_result.test_statistic,
        "p_value": gpy_result.p_value,
    }


tasks = []
for T in [40, 50, 80, 150, 200]:
    for M in [40, 50, 80, 150, 200]:
        task = (run, n_repeats, "non_linear_dependence", {"T": T, "M": M, "burn": burn})
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("non_linear_dependence")
df.with_columns(positive=(pl.col("test_statistic") > 1.4).cast(pl.Float64)).group_by(
    ["T", "M"]
).mean().to_pandas().pivot(index="T", columns=["M"], values=["positive"])
# Out:
#     positive
# M        40    50    80    150   200
# T
# 40      0.87  0.92  0.91  0.94  0.93
# 50      0.89  0.89  0.93  0.95  0.94
# 80      0.94  0.92  0.92  0.93  0.92
# 150     0.88  0.93  0.94  0.89  0.94
# 200     0.97  0.96  0.98  0.91  0.92

# %% [markdown]
# ## Factor model

# %%
def run(T: int, M: int, burn: int, K: int, time_ar: float, time_ma: float):
    y = factor_model_sample(T, M, burn, K, time_ar, time_ma)
    gpy_result = GPY(y, fs)
    return {
        "T": T,
        "M": M,
        "burn": burn,
        "test_statistic": gpy_result.test_statistic,
        "p_value": gpy_result.p_value,
    }


time_ar, time_ma = 0, 0.8
K_range = np.arange(1, 5)
T_M_range = [
    (50, 50),
    (50, 100),
    (100, 100),
    (200, 100),
    (300, 200),
    (200, 300),
    (100, 200),
    (200, 400),
    (400, 200),
    (100, 300),
    (300, 100),
]
tasks = []
for T, M in T_M_range:
    for K in K_range:
        task = (
            run,
            n_repeats,
            "factor_model",
            {
                "T": T,
                "M": M,
                "burn": burn,
                "K": K,
                "time_ar": time_ar,
                "time_ma": time_ma,
            },
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("factor_model")
positive_column_name = f"positive - {level:.0%}"
df.with_columns(positive=(pl.col("test_statistic") > 1.4).cast(pl.Float64)).group_by(
    ["T", "M", "K"]
).mean().to_pandas().pivot(index="T", columns=["M"], values=[positive_column_name])
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.24it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/alexisrosuel/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/Users/alexisrosuel/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/alexisrosuel/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/alexisrosuel/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/ng/g1qy_rr97098d2b5gwfq8_s40000gn/T/ipykernel_3508/2888992321.py", line 10, in run_batch
#   File "/var/folders/ng/g1qy_rr97098d2b5gwfq8_s40000gn/T/ipykernel_3508/2888992321.py", line 10, in <listcomp>
#   File "/var/folders/ng/g1qy_rr97098d2b5gwfq8_s40000gn/T/ipykernel_3508/390324167.py", line 3, in run
#   File "/Users/alexisrosuel/Library/Mobile Documents/com~apple~CloudDocs/Documents/Projets/recherche/gpy-test/src/gpy_test/gpy.py", line 72, in GPY
#     Cov = compute_covariance(
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/alexisrosuel/Library/Mobile Documents/com~apple~CloudDocs/Documents/Projets/recherche/gpy-test/src/gpy_test/covariance.py", line 194, in compute_covariance
#     _check_definite_non_negative(
#   File "/Users/alexisrosuel/Library/Mobile Documents/com~apple~CloudDocs/Documents/Projets/recherche/gpy-test/src/gpy_test/covariance.py", line 119, in _check_definite_non_negative
#     raise ValueError(msg)
# ValueError: Convergence issue: the limit covariance matrix is not definite non-negative: matrix=array([[6.55869079e+02+0.j, 9.77313149e+04+0.j],
#        [9.77313149e+04+0.j, 1.20488499e+07+0.j]]), eigs=array([-1.36845700e+02,  1.20496427e+07])
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 46
#      31         task = (
#      32             run,
#      33             n_repeats,
#    (...)
#      42             },
#      43         )
#      44         tasks.append(task)
# ---> 46 results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))
#      48 df = load_batch("factor_model")
#      49 positive_column_name = f"positive - {level:.0%}"
#
# File ~/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File ~/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File ~/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File ~/micromamba/envs/gpy-test-311/lib/python3.11/site-packages/joblib/parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# ValueError: Convergence issue: the limit covariance matrix is not definite non-negative: matrix=array([[6.55869079e+02+0.j, 9.77313149e+04+0.j],
#        [9.77313149e+04+0.j, 1.20488499e+07+0.j]]), eigs=array([-1.36845700e+02,  1.20496427e+07])

# %% [markdown]
# ## Common random dependence

# %%
def run(N: int, M: int, burn: int):
    y = white_arma_sample(
        N, M, burn, ar=0, ma=0, is_complex_gaussian=is_complex_gaussian
    )
    A = np.random.normal(0, 1, (M, M))
    y = y @ A
    gpy_result = GPY(y, fs, is_complex_gaussian=is_complex_gaussian)
    return {
        "T": T,
        "M": M,
        "burn": burn,
        "space_ar": space_ar,
        "space_ma": space_ma,
        "is_complex_gaussian": is_complex_gaussian,
        "test_statistic": gpy_result.test_statistic,
        "p_value": gpy_result.p_value,
    }


tasks = []
for T in T_range:
    for M in M_range:
        task = (
            run,
            n_repeats,
            "common_random_dependence",
            {"T": T, "M": M, "burn": burn},
        )
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("common_random_dependence")
df.with_columns(positive=(pl.col("p_value") > 1 - level).cast(pl.Float64)).group_by(
    ["T", "M"]
).mean().to_pandas().pivot(index="T", columns=["M"], values=["positive"])

# %% [markdown]
# ## Rank one dependence

# %%
def run(N: int, M: int, burn: int):
    u = 
    v = 
    y_1 = rank_one_sample(N, M, burn, ar=0, ma=0)
    y = white_arma_sample(N, M, burn, ar=0, ma=0, is_complex_gaussian=is_complex_gaussian)
    A = np.random.normal(0, 1, (M, M))
    y = y @ A
    gpy_result = GPY(y, fs, is_complex_gaussian=is_complex_gaussian)
    return {'N': N, 'M': M, 'burn': burn, 'space_ar': space_ar, 'space_ma': space_ma, 'is_complex_gaussian': is_complex_gaussian, 'test_statistic': gpy_result.test_statistic, 'p_value': gpy_result.p_value}

    gpy_result = GPY(y, fs)
    return {'N': N, 'M': M, 'burn': burn, 'test_statistic': gpy_result.test_statistic, 'p_value': gpy_result.p_value}

tasks = []
for N in N_range:
    for M in M_range: 
        task = (run, n_repeats, 'rank_one_dependence', {'N': N, 'M': M, 'burn': burn})
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch('rank_one_dependence')
df.with_columns(positive=(pl.col('p_value') > 1-level).cast(pl.Float64)).group_by(['N', 'M']).mean().to_pandas().pivot(index='N', columns=['M'], values=['positive'])

# %% [markdown]
# # ARCH

# %%
def run(N: int, M: int, burn: int):
    y = arch_sample(
        N,
        M,
        burn,
    )
    gpy_result = GPY(y, fs, is_complex_gaussian=is_complex_gaussian)
    return {
        "N": N,
        "M": M,
        "burn": burn,
        "space_ar": space_ar,
        "space_ma": space_ma,
        "is_complex_gaussian": is_complex_gaussian,
        "test_statistic": gpy_result.test_statistic,
        "p_value": gpy_result.p_value,
    }

    gpy_result = GPY(y, fs)
    return {
        "N": N,
        "M": M,
        "burn": burn,
        "test_statistic": gpy_result.test_statistic,
        "p_value": gpy_result.p_value,
    }


tasks = []
for N in N_range:
    for M in M_range:
        task = (run, n_repeats, "arch", {"N": N, "M": M, "burn": burn})
        tasks.append(task)

results = Parallel(n_jobs=-1)(delayed(run_batch)(*task) for task in tqdm(tasks))

df = load_batch("arch")
df.with_columns(positive=(pl.col("p_value") > 1 - level).cast(pl.Float64)).group_by(
    ["N", "M"]
).mean().to_pandas().pivot(index="N", columns=["M"], values=["positive"])
